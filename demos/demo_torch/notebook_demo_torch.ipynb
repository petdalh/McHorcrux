# %%
import time
# Imports Gunnerus model
from mchorcrux.torch_core.simulator.vessels.csad_torch import CSAD_6DOF


# Imports waves
from mchorcrux.torch_core.simulator.waves.wave_load_torch import WaveLoad
from mchorcrux.torch_core.simulator.waves.wave_spectra_torch import JONSWAP

# Imports utilities
import math
import torch
import matplotlib.pyplot as plt


import cProfile, pstats, io

# %%
start = time.time()

dt = 0.01
simtime = 100
t = torch.arange(0, simtime, dt)

vessel = CSAD_6DOF(dt=dt, method='RK4')
print(f"Init boat took {time.time() - start:.2f} seconds")

eta = torch.zeros((6, len(t)))
nu = torch.zeros((6, len(t)))
wave_load = torch.zeros((6, len(t)))
# Out:
# Init boat took 0.16 seconds

# %%
Uc = 0.0
beta_c = 0

start = time.time()
hs = 5.0/90 # Significant wave height
tp = 9.0*math.sqrt(1/90) # Peak period (be careful using math.sqrt. Use that were tensor is not needed, but only the number)
gamma = 3.3 # Peak factor
N = 100 

# Discretize freq range
wp = 2.*math.pi / tp
wmin, wmax = wp/2., 3.*wp
dw = (wmax - wmin)/N
w = torch.linspace(wmin, wmax, N)


# JONSWAP in PyTorch
jonswap = JONSWAP(w) #accept numpy or torch tensor
freq, spec = jonswap(hs, tp, gamma)  # freq, spec both Tensors
wave_amps = torch.sqrt(2.0 * spec * dw)
eps = torch.rand(N) * (2 * math.pi)
wave_dir = torch.ones(N) * (math.pi / 4.0)

# DiffWaveLoad expects wave_amps, freqs, eps, angles as NumPy or Torch Tensors
waveload = WaveLoad(
    wave_amps,
    freq, #accepts as numpy or torch tensor
    eps,
    wave_dir,
    config_file=vessel._config_file,
    interpolate=True,
    qtf_method="Newman",
    deep_water=True
)
print(f"Init the everything related to the waves took {time.time() - start:.2f} seconds")
print(vessel._eta.device)
# Out:
# Init the everything related to the waves took 0.42 seconds
# cpu

# %%
# Define initial state explicitly for this cell's runs
eta_init = torch.zeros(6, dtype=torch.float32)
nu_init = torch.zeros(6, dtype=torch.float32)

# Define the simulation loop as a function
def run_simulation_loop(vessel, waveload_obj, time_vec, Uc_val, beta_c_val, tau_ctrl):
    num_steps = len(time_vec)
    # Pre-allocate tensors on the same device as vessel state if possible
    # Assuming vessel state (eta, nu) is on CPU by default unless moved
    device = vessel._eta.device # Get device from vessel's tensor (Use _eta)
    eta_hist = torch.zeros((6, num_steps), dtype=torch.float32, device=device)
    nu_hist = torch.zeros((6, num_steps), dtype=torch.float32, device=device)
    wave_load_hist = torch.zeros((6, num_steps), dtype=torch.float32, device=device)

    # Ensure tau_ctrl is on the correct device and dtype
    tau_ctrl = tau_ctrl.to(device=device, dtype=torch.float32)

    for i in range(num_steps):
        current_eta = vessel.get_eta()
        eta_hist[:, i] = current_eta
        nu_hist[:, i] = vessel.get_nu()

        # Calculate wave load - assuming waveload_obj returns a tensor
        tau_wave = waveload_obj(time_vec[i], current_eta)
        # Ensure tau_wave is a tensor on the correct device/dtype
        # (Add assertion or explicit conversion if waveload_obj might return numpy/list)
        if not isinstance(tau_wave, torch.Tensor):
             # Example: Convert if it's numpy, adjust as needed
             tau_wave = torch.tensor(tau_wave, dtype=torch.float32, device=device)
        else:
             tau_wave = tau_wave.to(device=device, dtype=torch.float32)

        wave_load_hist[:, i] = tau_wave

        # Calculate total tau - should result in a float32 tensor
        tau = tau_ctrl + tau_wave

        # Integrate - vessel.integrate should handle the tensor type internally
        vessel.integrate(Uc_val, beta_c_val, tau)

    return eta_hist, nu_hist, wave_load_hist

# %%
# --- Simulation Execution ---
# Non-compiled version (for comparison)
print("Starting non-compiled simulation")
vessel_non_compiled = CSAD_6DOF(dt=dt, method='RK4')
vessel_non_compiled.set_eta(eta_init.clone())
vessel_non_compiled.set_nu(nu_init.clone())
tau_control_non_compiled = torch.tensor([0, 0, 0, 0, 0, 0], dtype=torch.float32)

profiler_non_compiled = cProfile.Profile()
start_non_compiled = time.time()
profiler_non_compiled.enable()
eta_non_compiled, nu_non_compiled, wave_load_non_compiled = run_simulation_loop(
    vessel_non_compiled, waveload, t, Uc, beta_c, tau_control_non_compiled
)
profiler_non_compiled.disable()
end_non_compiled = time.time()
non_compiled_time = end_non_compiled - start_non_compiled
print(f"Non-compiled simulation took {non_compiled_time:.2f} seconds")


if non_compiled_time > 0:
    print(f"Simtime/Real: {simtime / non_compiled_time:.2f}")
print("\n--- Non-compiled Profile --- ")
s_non_compiled = io.StringIO()
ps_non_compiled = pstats.Stats(profiler_non_compiled, stream=s_non_compiled).sort_stats('cumulative')
ps_non_compiled.print_stats(20) # Print top 20 functions
print(s_non_compiled.getvalue())
# Out:
# Starting non-compiled simulation
# Non-compiled simulation took 53.12 seconds
# Simtime/Real: 1.88
#
# --- Non-compiled Profile ---
#          6689396 function calls (6649083 primitive calls) in 53.087 seconds
#
#    Ordered by: cumulative time
#    List reduced from 369 to 20 due to restriction <20>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         2    0.000    0.000   53.116   26.558 /home/kmroen/miniconda3/envs/tensor/lib/python3.9/site-packages/IPython/core/interactiveshell.py:3514(run_code)
#      21/2    0.000    0.000   53.116   26.558 {built-in method builtins.exec}
#         1    0.000    0.000   53.116   53.116 /tmp/ipykernel_45511/1588504569.py:12(<module>)
#         1    0.784    0.784   53.116   53.116 /tmp/ipykernel_45511/495480234.py:6(run_simulation_loop)
#     10000    0.335    0.000   29.054    0.003 /home/kmroen/projects/McHorcrux/torch_core/simulator/vessels/vessel_torch.py:79(integrate)
#     10000    1.706    0.000   28.153    0.003 /home/kmroen/projects/McHorcrux/torch_core/simulator/vessels/vessel_torch.py:95(RK4)
#     40000    4.231    0.000   26.447    0.001 /home/kmroen/projects/McHorcrux/torch_core/simulator/vessels/csad_torch.py:68(x_dot)
#     10000    0.061    0.000   23.213    0.002 /home/kmroen/miniconda3/envs/tensor/lib/python3.9/site-packages/torch/nn/modules/module.py:1747(_wrapped_call_impl)
#     10000    0.133    0.000   23.153    0.002 /home/kmroen/miniconda3/envs/tensor/lib/python3.9/site-packages/torch/nn/modules/module.py:1755(_call_impl)
#     10000    0.370    0.000   22.975    0.002 /home/kmroen/projects/McHorcrux/torch_core/simulator/waves/wave_load_torch.py:148(forward)
#     40000    0.813    0.000   16.285    0.000 /home/kmroen/projects/McHorcrux/torch_core/utils.py:91(J_torch)
#     10000    5.434    0.001   15.985    0.002 /home/kmroen/projects/McHorcrux/torch_core/simulator/waves/wave_load_torch.py:179(second_order_loads)
#     40000    1.012    0.000   10.455    0.000 /home/kmroen/projects/McHorcrux/torch_core/utils.py:62(Rzyx_torch)
#     80000    1.427    0.000    6.661    0.000 /home/kmroen/projects/McHorcrux/torch_core/utils.py:36(Rz_torch)
#     10000    0.872    0.000    6.620    0.001 /home/kmroen/projects/McHorcrux/torch_core/simulator/waves/wave_load_torch.py:157(first_order_loads)
#     10000    0.534    0.000    6.509    0.001 /home/kmroen/miniconda3/envs/tensor/lib/python3.9/site-packages/torch/functional.py:225(einsum)
#   1030000    6.012    0.000    6.012    0.000 {built-in method torch.tensor}
#    840000    5.980    0.000    5.980    0.000 {built-in method torch.stack}
#     10000    2.699    0.000    4.409    0.000 /home/kmroen/projects/McHorcrux/torch_core/simulator/waves/wave_load_torch.py:236(_rao_interp)
#     40000    1.368    0.000    3.995    0.000 /home/kmroen/projects/McHorcrux/torch_core/utils.py:69(Tzyx_torch)

# %%
# Compiled version
print("\nStarting compiled simulation")
vessel_compiled = CSAD_6DOF(dt=dt, method='RK4')
vessel_compiled.set_eta(eta_init.clone())
vessel_compiled.set_nu(nu_init.clone())
tau_control_compiled = torch.tensor([0, 0, 0, 0, 0, 0], dtype=torch.float32)

# Compile the entire loop function using 'reduce-overhead' mode
print("Compiling simulation loop function (mode='reduce-overhead')...")
compiled_run_simulation_loop = torch.compile(run_simulation_loop, mode='reduce-overhead')

# Run the compiled function (first run includes compile time)
print("Running compiled function (includes compile time)...")
profiler_compile_run = cProfile.Profile()
start_compile_run = time.time()
profiler_compile_run.enable()
eta_compiled, nu_compiled, wave_load_compiled = compiled_run_simulation_loop(
    vessel_compiled, waveload, t, Uc, beta_c, tau_control_compiled
)
profiler_compile_run.disable()
end_compile_run = time.time()
compile_time = end_compile_run - start_compile_run
print(f"Compiled simulation (including compile time) took {compile_time:.2f} seconds")
print("\n--- Compiled Profile (First Run) --- ")
s_compile_run = io.StringIO()
ps_compile_run = pstats.Stats(profiler_compile_run, stream=s_compile_run).sort_stats('cumulative')
ps_compile_run.print_stats(20) # Print top 20 functions
print(s_compile_run.getvalue())
# Out:
# Starting compiled simulation
# Compiling simulation loop function (mode='reduce-overhead')...
# Running compiled function (includes compile time)...
# Compiled simulation (including compile time) took 35.47 seconds
#
# --- Compiled Profile (First Run) ---
#          10747481 function calls (10645431 primitive calls) in 26.406 seconds
#
#    Ordered by: cumulative time
#    List reduced from 4417 to 20 due to restriction <20>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         2    0.000    0.000   35.473   17.737 /home/kmroen/miniconda3/envs/tensor/lib/python3.9/site-packages/IPython/core/interactiveshell.py:3514(run_code)
#     176/2    0.004    0.000   35.473   17.737 {built-in method builtins.exec}
#         1    0.000    0.000   35.473   35.473 /tmp/ipykernel_45511/159602394.py:17(<module>)
#         1    0.000    0.000   35.473   35.473 /home/kmroen/miniconda3/envs/tensor/lib/python3.9/site-packages/torch/_dynamo/eval_frame.py:619(_fn)
#         1    1.423    1.423   34.976   34.976 /tmp/ipykernel_45511/495480234.py:6(run_simulation_loop)
# 50156/50147    0.264    0.000   24.637    0.000 /home/kmroen/miniconda3/envs/tensor/lib/python3.9/site-packages/torch/_dynamo/eval_frame.py:829(_fn)
#     50000    0.149    0.000   23.874    0.000 /home/kmroen/miniconda3/envs/tensor/lib/python3.9/site-packages/torch/_functorch/aot_autograd.py:1197(forward)
#     50000    0.499    0.000   23.700    0.000 /home/kmroen/miniconda3/envs/tensor/lib/python3.9/site-packages/torch/_functorch/_aot_autograd/runtime_wrappers.py:291(runtime_wrapper)
#     50000    0.275    0.000   22.599    0.000 /home/kmroen/miniconda3/envs/tensor/lib/python3.9/site-packages/torch/_functorch/_aot_autograd/utils.py:116(call_func_at_runtime_with_args)
#     10000    0.046    0.000   22.575    0.002 /home/kmroen/miniconda3/envs/tensor/lib/python3.9/site-packages/torch/nn/modules/module.py:1747(_wrapped_call_impl)
#     10000    0.445    0.000   22.528    0.002 /home/kmroen/miniconda3/envs/tensor/lib/python3.9/site-packages/torch/nn/modules/module.py:1755(_call_impl)
#     50000    0.069    0.000   22.163    0.000 /home/kmroen/miniconda3/envs/tensor/lib/python3.9/site-packages/torch/_functorch/_aot_autograd/runtime_wrappers.py:481(wrapper)
#     50000    1.090    0.000   22.095    0.000 /home/kmroen/miniconda3/envs/tensor/lib/python3.9/site-packages/torch/_inductor/output_code.py:457(__call__)
#     10000    0.691    0.000   16.311    0.002 /home/kmroen/projects/McHorcrux/torch_core/simulator/waves/wave_load_torch.py:148(forward)
#     10000    0.592    0.000   12.943    0.001 /home/kmroen/projects/McHorcrux/torch_core/simulator/waves/wave_load_torch.py:179(second_order_loads)
#     10000    0.040    0.000   11.667    0.001 /home/kmroen/projects/McHorcrux/torch_core/simulator/waves/wave_load_torch.py:216(torch_dynamo_resume_in_second_order_loads_at_216)
#     10000    1.042    0.000   11.033    0.001 /tmp/torchinductor_kmroen/r6/cr65eoyny7e373slhakwacvn5suzblrld2nifwsybp4rzaubeu2n.py:62(call)
#     10000    0.043    0.000    9.972    0.001 /home/kmroen/projects/McHorcrux/torch_core/simulator/vessels/vessel_torch.py:79(integrate)
# 271557/270961    0.256    0.000    9.422    0.000 /home/kmroen/miniconda3/envs/tensor/lib/python3.9/site-packages/torch/_ops.py:755(__call__)
#     10000    1.862    0.000    8.679    0.001 /tmp/torchinductor_kmroen/kk/ckkl7durbddbdkqmy3whvofzeb3e3eerxmmgnepiccemzpkbxq3u.py:4836(call)

# %%
# Run the compiled function again (should be faster, uses cache)
print("\nRunning compiled function again (cached)...")
# Reset state using a new vessel instance for a clean timing run
vessel_compiled_rerun = CSAD_6DOF(dt=dt, method='RK4')
vessel_compiled_rerun.set_eta(eta_init.clone())
vessel_compiled_rerun.set_nu(nu_init.clone())

profiler_compiled_rerun = cProfile.Profile()
start_compiled_rerun = time.time()
profiler_compiled_rerun.enable()
eta_compiled_rerun, nu_compiled_rerun, wave_load_compiled_rerun = compiled_run_simulation_loop(
    vessel_compiled_rerun, waveload, t, Uc, beta_c, tau_control_compiled
)
profiler_compiled_rerun.disable()
end_compiled_rerun = time.time()
rerun_time = end_compiled_rerun - start_compiled_rerun
print(f"Compiled simulation rerun took {rerun_time:.2f} seconds")
if rerun_time > 0:
    print(f"Simtime/Real (cached): {simtime / rerun_time:.2f}")
else:
    print("Rerun was too fast to measure Simtime/Real accurately.")
print("\n--- Compiled Profile (Cached Run) --- ")
s_compiled_rerun = io.StringIO()
ps_compiled_rerun = pstats.Stats(profiler_compiled_rerun, stream=s_compiled_rerun).sort_stats('cumulative')
ps_compiled_rerun.print_stats(20) # Print top 20 functions
print(s_compiled_rerun.getvalue())

# Store results from the faster (rerun) compiled version for plotting
eta = eta_compiled_rerun
nu = nu_compiled_rerun
wave_load = wave_load_compiled_rerun
# Out:
# Running compiled function again (cached)...
# Compiled simulation rerun took 28.23 seconds
# Simtime/Real (cached): 3.54
#
# --- Compiled Profile (Cached Run) ---
#          7610076 function calls in 19.689 seconds
#
#    Ordered by: cumulative time
#    List reduced from 112 to 20 due to restriction <20>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         2    0.000    0.000   28.225   14.113 /home/kmroen/miniconda3/envs/tensor/lib/python3.9/site-packages/IPython/core/interactiveshell.py:3514(run_code)
#         2    0.000    0.000   28.225   14.113 {built-in method builtins.exec}
#         1    0.000    0.000   28.225   28.225 /tmp/ipykernel_45511/788679144.py:11(<module>)
#         1    0.000    0.000   28.225   28.225 /home/kmroen/miniconda3/envs/tensor/lib/python3.9/site-packages/torch/_dynamo/eval_frame.py:619(_fn)
#         1    1.404    1.404   28.225   28.225 /tmp/ipykernel_45511/495480234.py:6(run_simulation_loop)
#     50000    0.260    0.000   24.544    0.000 /home/kmroen/miniconda3/envs/tensor/lib/python3.9/site-packages/torch/_dynamo/eval_frame.py:829(_fn)
#     50000    0.143    0.000   24.013    0.000 /home/kmroen/miniconda3/envs/tensor/lib/python3.9/site-packages/torch/_functorch/aot_autograd.py:1197(forward)
#     50000    0.489    0.000   23.846    0.000 /home/kmroen/miniconda3/envs/tensor/lib/python3.9/site-packages/torch/_functorch/_aot_autograd/runtime_wrappers.py:291(runtime_wrapper)
#     50000    0.260    0.000   22.761    0.000 /home/kmroen/miniconda3/envs/tensor/lib/python3.9/site-packages/torch/_functorch/_aot_autograd/utils.py:116(call_func_at_runtime_with_args)
#     50000    0.067    0.000   22.341    0.000 /home/kmroen/miniconda3/envs/tensor/lib/python3.9/site-packages/torch/_functorch/_aot_autograd/runtime_wrappers.py:481(wrapper)
#     50000    1.093    0.000   22.274    0.000 /home/kmroen/miniconda3/envs/tensor/lib/python3.9/site-packages/torch/_inductor/output_code.py:457(__call__)
#     10000    0.046    0.000   16.692    0.002 /home/kmroen/miniconda3/envs/tensor/lib/python3.9/site-packages/torch/nn/modules/module.py:1747(_wrapped_call_impl)
#     10000    0.448    0.000   16.647    0.002 /home/kmroen/miniconda3/envs/tensor/lib/python3.9/site-packages/torch/nn/modules/module.py:1755(_call_impl)
#     10000    0.702    0.000   16.113    0.002 /home/kmroen/projects/McHorcrux/torch_core/simulator/waves/wave_load_torch.py:148(forward)
#     10000    0.598    0.000   12.921    0.001 /home/kmroen/projects/McHorcrux/torch_core/simulator/waves/wave_load_torch.py:179(second_order_loads)
#     10000    0.038    0.000   11.746    0.001 /home/kmroen/projects/McHorcrux/torch_core/simulator/waves/wave_load_torch.py:216(torch_dynamo_resume_in_second_order_loads_at_216)
#     10000    1.036    0.000   11.139    0.001 /tmp/torchinductor_kmroen/r6/cr65eoyny7e373slhakwacvn5suzblrld2nifwsybp4rzaubeu2n.py:62(call)
#     10000    0.042    0.000   10.021    0.001 /home/kmroen/projects/McHorcrux/torch_core/simulator/vessels/vessel_torch.py:79(integrate)
#    270000    0.232    0.000    9.362    0.000 /home/kmroen/miniconda3/envs/tensor/lib/python3.9/site-packages/torch/_ops.py:755(__call__)
#     10000    1.853    0.000    8.729    0.001 /tmp/torchinductor_kmroen/kk/ckkl7durbddbdkqmy3whvofzeb3e3eerxmmgnepiccemzpkbxq3u.py:4836(call)

# %%
fig, axes = plt.subplots(nrows=2, ncols=1, figsize=(10, 6))
axes[0].plot(t, eta[0, :], label='x')
axes[0].plot(t, eta[1, :], label='y')
axes[0].plot(t, eta[2, :], label='z')
axes[0].legend()
axes[0].grid()
axes[0].set_xlabel('Time [s]')
axes[0].set_ylabel('Position [m]')
axes[0].set_title('Position')

axes[1].plot(t, eta[5, :], label=r"$\psi$")
axes[1].legend()
axes[1].grid()
axes[1].set_xlabel('Time [s]')
axes[1].set_ylabel('Angle [rad]')
axes[1].set_title('Angle')

plt.show()


# Plot XY plot to position
plt.figure()
plt.plot(eta[0, :], eta[1, :])
plt.grid()
plt.xlabel('x [m]')
plt.ylabel('y [m]')
plt.title('XY plot')
plt.show()

# %%
# ----------------------------------------------------------------------------
# Plot the wave loads vs time for each degree of freedom (DOF)
# ----------------------------------------------------------------------------

fig, axes = plt.subplots(nrows=6, ncols=1, figsize=(10, 12), sharex=True)
dof_labels = ['Surge', 'Sway', 'Heave', 'Roll', 'Pitch', 'Yaw']

for i in range(6):
    axes[i].plot(t, wave_load[i, :], label=f'{dof_labels[i]}')
    axes[i].set_ylabel('Wave load')
    axes[i].legend()
    axes[i].grid()

axes[-1].set_xlabel('Time [s]')
fig.suptitle('Wave Loads vs Time for Each DOF', y=0.95)  # Adjusted y position
plt.tight_layout(rect=[0, 0, 1, 0.96])  # Leave space for the suptitle
plt.show()
